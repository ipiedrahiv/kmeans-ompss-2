# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cpp_results = pd.read_csv("/home/bscuser/Workspace/pe/kmeans-ompss-2/c_implementation/pointlabel.csv", names = ["x", "y", "c"])
cpp_results
# Out:
#              x         y  c
# 0    -3.372200 -4.072650  6
# 1    -0.998914  0.472515  0
# 2    -0.781695  2.214180  0
# 3    -3.155980 -1.542320  1
# 4    -0.800375  2.007810  0
# ...        ...       ... ..
# 9995 -0.882880  1.830450  0
# 9996 -2.861620  3.732490  0
# 9997 -3.098830  3.793900  0
# 9998 -1.001320  0.252765  5
# 9999 -0.919795  0.438764  5
#
# [10000 rows x 3 columns]

# %%
cpp_results.max()
# Out:
# x   -0.391243
# y    4.080290
# c    6.000000
# dtype: float64

# %%
sns.scatterplot(x=cpp_results["x"], y=cpp_results["y"], 
                hue=cpp_results["c"], 
                palette=sns.color_palette("tab10", n_colors=7))

plt.show()
